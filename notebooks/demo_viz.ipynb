# %%
import sys, os
sys.path.append(os.path.abspath('..'))

from mcf2swc import show_swc

import pyvista as pv
pv.set_jupyter_backend("trame")

show_swc("../data/swc/TS2_trace_section_median.swc")
# Out:
# Widget(value='<iframe src="http://localhost:57757/index.html?ui=P_0x290c8dd68a0_0&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_equivalent_area.swc")
# Out:
# Widget(value='<iframe src="http://localhost:57757/index.html?ui=P_0x290c9b86930_1&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_equivalent_perimeter.swc")
# Out:
# Widget(value='<iframe src="http://localhost:57757/index.html?ui=P_0x29082a4e360_2&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_nearest_surface.swc")
# Out:
# Widget(value='<iframe src="http://localhost:57757/index.html?ui=P_0x290c94ce9f0_3&reconnect=auto" class="pyvis…

# %%
show_swc("../data/swc/TS2_trace_section_circle_fit.swc")
# Out:
# Widget(value='<iframe src="http://localhost:57757/index.html?ui=P_0x290cfd23530_4&reconnect=auto" class="pyvis…
